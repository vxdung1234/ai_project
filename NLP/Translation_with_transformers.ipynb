# %% [markdown]
# # Install library

# %%
# !pip install transformers datasets sentencepiece bert-score sacrebleu sacremoses

# %% [markdown]
# # Load dataset for en-vi from kde4

# %%
from datasets import load_dataset
#Load dataset from kde4 for en-vi
data = load_dataset('kde4', lang1='en', lang2='vi')
data
# Out:
# WARNING:datasets.builder:Found cached dataset kde4 (/root/.cache/huggingface/datasets/kde4/en-vi-lang1=en,lang2=vi/0.0.0/243129fb2398d5b0b4f7f6831ab27ad84774b7ce374cf10f60f6e1ff331648ac)
#   0%|          | 0/1 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 42782
#     })
# })

# %%
# Get 5000 samples
small = data['train'].shuffle(seed=42).select(range(5000))
# Out:
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/kde4/en-vi-lang1=en,lang2=vi/0.0.0/243129fb2398d5b0b4f7f6831ab27ad84774b7ce374cf10f60f6e1ff331648ac/cache-5f73bee428d3e105.arrow

# %%
# Split train test dataset
ds = small.train_test_split(seed=42)
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 3750
#     })
#     test: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 1250
#     })
# })

# %%
ds['train'][0]
# Out:
# {'id': '20684', 'translation': {'en': 'Allylisothiocyanate', 'vi': 'Name'}}

# %%
import numpy as np

train = ds['train']['translation']
# Get max_input_len > 95% 
input_lens = [len(tr['en']) for tr in train]
max_input_len = int(np.percentile(input_lens,95))
max_input_len
# Out:
# 103

# %%
# Get max_target_len > 95% 
target_lens = [len(tr['vi']) for tr in train]
max_target_len = int(np.percentile(target_lens,95))
max_target_len
# Out:
# 93

# %%
from transformers import AutoTokenizer

#Load tokenizer form pretrained model
checkpoint = 'Helsinki-NLP/opus-mt-en-vi'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# %%
#Define tokenizer function
def tokenizer_fn(batch):
  #List text for en
  inputs = [x['en'] for x in batch['translation']]
  #List text for vi
  targets = [x['vi'] for x in batch['translation']]

  #Tokenizer with max_input_len and max_target_len
  tokenized_inputs = tokenizer(inputs, max_length=max_input_len, truncation=True)
  tokenized_targets = tokenizer(text_target=targets, max_length=max_target_len, truncation=True)

  #Add a labels column that matches the requirements transformers library
  tokenized_inputs['labels'] = tokenized_targets['input_ids']
  return tokenized_inputs

# %%
#Apply tokenizer for en_text and vi_text
tokenized_ds = ds.map(
    tokenizer_fn,
    batched=True,
    #Remove unnecessary columns
    remove_columns=ds['train'].column_names
)
# Out:
# Map:   0%|          | 0/3750 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1250 [00:00<?, ? examples/s]

# %%
tokenized_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 3750
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 1250
#     })
# })

# %%
from transformers import AutoModelForSeq2SeqLM

#Download pretrained model from checkpoint
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)

# %%
from transformers import DataCollatorForSeq2Seq

#Create data_collator for convert torch tensor
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
from datasets import load_metric
#Load and test bert_metric
bert_metric = load_metric('bertscore')
bert_metric.compute(
    predictions=['Tôi đang học về dịch máy'],
    references=[['Tôi đã học dịch máy']],
    lang='vi'
)
# Out:
# <ipython-input-14-1d730c4e9bc3>:3: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   bert_metric = load_metric('bertscore')
# {'precision': [0.9314209222793579],
#  'recall': [0.9498319625854492],
#  'f1': [0.940536379814148],
#  'hashcode': 'bert-base-multilingual-cased_L9_no-idf_version=0.3.12(hug_trans=4.26.1)'}

# %%
#Load and test bleu_metric
bleu_metric = load_metric('sacrebleu')
bleu_metric.compute(
    predictions=['Tôi đang học về dịch máy'],
    references=[['Tôi đã học dịch máy']]
)
# Out:
# {'score': 19.304869754804482,
#  'counts': [4, 1, 0, 0],
#  'totals': [6, 5, 4, 3],
#  'precisions': [66.66666666666667, 20.0, 12.5, 8.333333333333334],
#  'bp': 1.0,
#  'sys_len': 6,
#  'ref_len': 5}

# %%
#Define compute_metrics function for evaluation
def compute_metrics(preds_and_labels):
  preds, labels = preds_and_labels

  # Convert predict to words
  decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

  #Replace any -100 label with pad_token_id
  labels = np.where(labels != -100, labels, tokenizer.pad_token_id)

  #Convert labels to words
  decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

  #Remove double leading whitespace
  #Put labels in the list that match the metrics' requirements
  decoded_preds = [pred.strip() for pred in decoded_preds]
  decoded_labels = [[label.strip()] for label in decoded_labels] 
  
  bleu_score = bleu_metric.compute(
      predictions=decoded_preds,
      references=decoded_labels
  )

  bert_score = bert_metric.compute(
      predictions=decoded_preds,
      references=decoded_labels,
      lang='vi'
  )
  return {
      'bleu': bleu_score['score'],
      'bert_score': np.mean(bert_score['f1'])
  }

# %%
from transformers import Seq2SeqTrainingArguments

checkpoint_path = '/content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/'
training_args = Seq2SeqTrainingArguments(
    checkpoint_path,
    evaluation_strategy='no', #No evaluation during training
    save_strategy='epoch',
    learning_rate=2e-5,
    per_device_eval_batch_size=64,
    per_device_train_batch_size=32,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=3,
    predict_with_generate=True, #During evaluation, generate predictions without knowing true targets fed into decoder
    fp16=True, #Use float16 instead of float32
)

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model, 
    training_args,
    train_dataset=tokenized_ds['train'],
    eval_dataset=tokenized_ds['test'], 
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Using cuda_amp half precision backend

# %%
#evaluate the model before training
trainer.evaluate(max_length=max_target_len)
# Out:
# ***** Running Evaluation *****
#   Num examples = 1250
#   Batch size = 64
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:59]
#     </div>
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
# {'eval_loss': 4.187745094299316,
#  'eval_bleu': 6.05495734150977,
#  'eval_bert_score': 0.6856014505863189,
#  'eval_runtime': 73.147,
#  'eval_samples_per_second': 17.089,
#  'eval_steps_per_second': 0.273}

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 3750
#   Num Epochs = 3
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 354
#   Number of trainable parameters = 71625216
#     <div>
#
#       <progress value='354' max='354' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [354/354 01:10, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-118
# Configuration saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-118/config.json
# Configuration saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-118/generation_config.json
# Model weights saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-118/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-118/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-118/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-24] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-236
# Configuration saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-236/config.json
# Configuration saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-236/generation_config.json
# Model weights saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-236/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-236/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-236/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-48] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-354
# Configuration saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-354/config.json
# Configuration saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-354/generation_config.json
# Model weights saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-354/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-354/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-354/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/udemy_course/saved_model/translation/checkpoint/checkpoint-72] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=354, training_loss=1.8706511589093398, metrics={'train_runtime': 71.0274, 'train_samples_per_second': 158.39, 'train_steps_per_second': 4.984, 'total_flos': 155465846489088.0, 'train_loss': 1.8706511589093398, 'epoch': 3.0})

# %%
#evaluate the model after training, and the model has been improved 
trainer.evaluate(max_length=max_target_len)
# Out:
# ***** Running Evaluation *****
#   Num examples = 1250
#   Batch size = 64
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#     <div>
#
#       <progress value='40' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 03:05]
#     </div>
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       53684
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 53684,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 53684,
#   "transformers_version": "4.26.1"
# }
# {'eval_loss': 1.4573534727096558,
#  'eval_bleu': 48.64683606181376,
#  'eval_bert_score': 0.8613185623168945,
#  'eval_runtime': 49.0241,
#  'eval_samples_per_second': 25.498,
#  'eval_steps_per_second': 0.408,
#  'epoch': 3.0}

# %%
save_path = '/content/drive/MyDrive/udemy_course/saved_model/translation/'
trainer.save_model(save_path)
# Out:
# Saving model checkpoint to /content/drive/MyDrive/udemy_course/saved_model/translation/
# Configuration saved in /content/drive/MyDrive/udemy_course/saved_model/translation/config.json
# Configuration saved in /content/drive/MyDrive/udemy_course/saved_model/translation/generation_config.json
# Model weights saved in /content/drive/MyDrive/udemy_course/saved_model/translation/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/udemy_course/saved_model/translation/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/udemy_course/saved_model/translation/special_tokens_map.json

# %%
from transformers import pipeline
#Use fine tune model 
save_path = '/content/drive/MyDrive/udemy_course/saved_model/translation/'
translator = pipeline('translation', model=save_path)

# %%
translator("Always remember us this way")
# Out:
# [{'translation_text': '♪ Hãy luôn nhớ đến chúng con theo cách này'}]

# %%
translator("you are the reason")
# Out:
# [{'translation_text': 'bạn là lý do'}]

# %%
translator("waiting for love")
# Out:
# [{'translation_text': '♪ chờ đợi tình yêu ♪'}]

# %%
translator('Do you understand?')
# Out:
# [{'translation_text': 'Hiểu chưa?'}]

# %%
translator("Can you speak english?")
# Out:
# [{'translation_text': 'Anh nói được tiếng Anh không?'}]
